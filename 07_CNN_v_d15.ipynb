# %% [markdown]
# ## Import the Relevant Libraries

# %%
# TensorFlow is a library containing multiple machine learning tasks
import tensorflow as tf

# %%
# Keras, a high-level neural networks API, that runs on top of TensorFlow
# Enables building deep neural networks
from tensorflow import keras

# %%
# Check what device is in use – CPU or GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 417227147769755246
# xla_global_id: -1
# ]

# %%
# Print the versions
print("\033[1m" + "\033[4m" + "Versions in Use" + "\033[0;0m") 
print("TensorFlow: ", tf.__version__)
print("Keras: ", keras.__version__)
# Out:
# Versions in Use
# TensorFlow:  2.11.0
# Keras:  2.11.0

# %%
# Import the backend module from TensorFlow's Keras API and aliases it as K
from tensorflow.keras import backend as K

# %%
# Ensure the Keras session are cleared
K.clear_session()

# %%
# Used to instantiate a Keras tensor
from keras import Input

# %%
# Layers are the basic building blocks of neural networks in Keras
from keras import layers

# %%
# Allows for creation of neural network models
from keras.models import Model

# %%
# Allows for generation of tf.data.Dataset from image files in a directory
from tensorflow.keras.utils import image_dataset_from_directory

# %%
# Provides various algorithms for optimizing neural network training, such as SGD, Adam, RMSprop, etc.
from keras import optimizers

# %%
# Allows for implementation of early stopping in callbacks
from keras.callbacks import EarlyStopping

# %%
# Allows for implementation of reduce learning rate on plateau in callbacks
from keras.callbacks import ReduceLROnPlateau

# %%
# Allows for implementation of model check points in callbacks
from keras.callbacks import ModelCheckpoint

# %%
# Allows for implementation of TensorBoard in callbacks
from keras.callbacks import TensorBoard

# %%
# Needed for TensorBoard 
import datetime

# %%
# Allows for the computation of the cross-entropy loss between true labels and predicted labels
from keras import losses

# %%
# Allows for judging the performance of the model
from keras import metrics

# %%
# Allows for defining a parallel dataset using Python code
from tensorflow.keras.utils import Sequence

# %%
# Allows for plotting of figures 
import matplotlib.pyplot as plt

# %%
# Allows for plotting of confusion matrix heatmap 
import seaborn as sns

# %%
# Allows for creating of classification report and confusion matrix  
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Allows for the use of np.concatenate for the y-true values
import numpy as np

# %% [markdown]
# ## Variables in Use

# %%
# Define image width and height
size_w = 768
size_h = 768

# Define the batch size used
bch_size = 8

# Define seed used for shuffle
shuf_seed = 7

# Define the interpolation used
inter_pol = "lanczos5"

# %% [markdown]
# ## Creating the Model with Keras API

# %%
# Input CC view
input_cc = Input(shape = (size_h, size_w, 1), name = "input_cc")

# Rescale
image_rescale_cc = layers.Rescaling(scale = 1./255, name = "image_rescale_cc")(input_cc)


# ..............................................
# First convolutional layer
conv_1_cc = layers.Conv2D(16, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_1_cc")(image_rescale_cc)
conv_1_cc = layers.BatchNormalization(name = "bn_1_cc")(conv_1_cc)

max_1_cc = layers.MaxPooling2D(pool_size = (2, 2), padding = "same", name = "max_1_cc")(conv_1_cc)


# ..............................................
# Second convolutional layer
conv_2_cc_1 = layers.Conv2D(32, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_2_cc_1")(max_1_cc)
conv_2_cc_1 = layers.BatchNormalization(name = "bn_2_cc_1")(conv_2_cc_1)

conv_2_cc_2 = layers.Conv2D(32, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_2_cc_2")(conv_2_cc_1)
conv_2_cc_2 = layers.BatchNormalization(name = "bn_2_cc_2")(conv_2_cc_2)

conv_2_cc = layers.Add(name = "add_1_cc")([conv_2_cc_1, conv_2_cc_2])

max_2_cc = layers.MaxPooling2D(pool_size = (2, 2), name = "max_2_cc")(conv_2_cc)


# ..............................................
# Third convolutional layer
conv_3_cc_1 = layers.Conv2D(64, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_3_cc_1")(max_2_cc)
conv_3_cc_1 = layers.BatchNormalization(name = "bn_3_cc_1")(conv_3_cc_1)

conv_3_cc_2 = layers.Conv2D(64, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_3_cc_2")(conv_3_cc_1)
conv_3_cc_2 = layers.BatchNormalization(name = "bn_3_cc_2")(conv_3_cc_2)

conv_3_cc = layers.Add(name = "add_2_cc")([conv_3_cc_1, conv_3_cc_2])

max_3_cc = layers.MaxPooling2D(pool_size = (2, 2), name = "max_3_cc")(conv_3_cc)


# ..............................................
# Fourth convolutional layer
conv_4_cc_1 = layers.Conv2D(128, kernel_size = (5, 5), activation = "relu", strides = (2, 2), padding = "same", name = "conv_4_cc_1")(max_3_cc)
conv_4_cc_1 = layers.BatchNormalization(name = "bn_4_cc_1")(conv_4_cc_1)

conv_4_cc_2 = layers.Conv2D(128, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_4_cc_2")(conv_4_cc_1)
conv_4_cc_2 = layers.BatchNormalization(name = "bn_4_cc_2")(conv_4_cc_2)

conv_4_cc = layers.Add(name = "add_3_cc")([conv_4_cc_1, conv_4_cc_2])

max_4_cc = layers.MaxPooling2D(pool_size = (2, 2), name = "max_4_cc")(conv_4_cc)


# ..............................................
# Fifth convolutional layer
conv_5_cc_1 = layers.Conv2D(256, kernel_size = (5, 5), activation = "relu", strides = (2, 2), padding = "same", name = "conv_5_cc_1")(max_4_cc)
conv_5_cc_1 = layers.BatchNormalization(name = "bn_5_cc_1")(conv_5_cc_1)

conv_5_cc_2 = layers.Conv2D(256, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_5_cc_2")(conv_5_cc_1)
conv_5_cc_2 = layers.BatchNormalization(name = "bn_5_cc_2")(conv_5_cc_2)

conv_5_cc = layers.Add(name = "add_4_cc")([conv_5_cc_1, conv_5_cc_2])

max_5_cc = layers.MaxPooling2D(pool_size = (2, 2), name = "max_5_cc")(conv_5_cc)




# -----------------------------------------------------------------------------------------------------------------
# Input MLO view
input_mlo = Input(shape = (size_h, size_w, 1), name = "input_mlo")

# Rescale
image_rescale_mlo = layers.Rescaling(scale = 1./255, name = "image_rescale_mlo")(input_mlo)


# ..............................................
# First convolutional layer
conv_1_mlo = layers.Conv2D(16, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_1_mlo")(image_rescale_mlo)
conv_1_mlo = layers.BatchNormalization(name = "bn_1_mlo")(conv_1_mlo)

max_1_mlo = layers.MaxPooling2D((3, 3), strides = (2, 2), padding = "same", name = "max_1_mlo")(conv_1_mlo)


# ..............................................
# Second convolutional layer
conv_2_mlo_1 = layers.Conv2D(32, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_2_mlo_1")(max_1_mlo)
conv_2_mlo_1 = layers.BatchNormalization(name = "bn_2_mlo_1")(conv_2_mlo_1)

conv_2_mlo_2 = layers.Conv2D(32, kernel_size = (3, 3), activation = "relu", strides = (1, 1), padding = "same", name = "conv_2_mlo_2")(conv_2_mlo_1)
conv_2_mlo_2 = layers.BatchNormalization(name = "bn_2_mlo_2")(conv_2_mlo_2)

conv_2_mlo = layers.Add(name = "add_1_mlo")([conv_2_mlo_1, conv_2_mlo_2])

max_2_mlo = layers.MaxPooling2D(pool_size = (2, 2), name = "max_2_mlo")(conv_2_mlo)


# ..............................................
# Third convolutional layer
conv_3_mlo_1 = layers.Conv2D(64, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_3_mlo_1")(max_2_mlo)
conv_3_mlo_1 = layers.BatchNormalization(name = "bn_3_mlo_1")(conv_3_mlo_1)

conv_3_mlo_2 = layers.Conv2D(64, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_3_mlo_2")(conv_3_mlo_1)
conv_3_mlo_2 = layers.BatchNormalization(name = "bn_3_mlo_2")(conv_3_mlo_2)

conv_3_mlo = layers.Add(name = "add_2_mlo")([conv_3_mlo_1, conv_3_mlo_2])

max_3_mlo = layers.MaxPooling2D(pool_size = (2, 2), name = "max_3_mlo")(conv_3_mlo)


# ..............................................
# Fourth convolutional layer
conv_4_mlo_1 = layers.Conv2D(128, kernel_size = (5, 5), activation = "relu", strides = (2, 2), padding = "same", name = "conv_4_mlo_1")(max_3_mlo)
conv_4_mlo_1 = layers.BatchNormalization(name = "bn_4_mlo_1")(conv_4_mlo_1)

conv_4_mlo_2 = layers.Conv2D(128, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_4_mlo_2")(conv_4_mlo_1)
conv_4_mlo_2 = layers.BatchNormalization(name = "bn_4_mlo_2")(conv_4_mlo_2)

conv_4_mlo = layers.Add(name = "add_3_mlo")([conv_4_mlo_1, conv_4_mlo_2])

max_4_mlo = layers.MaxPooling2D(pool_size = (2, 2), name = "max_4_mlo")(conv_4_mlo)


# ..............................................
# Fifth convolutional layer
conv_5_mlo_1 = layers.Conv2D(256, kernel_size = (5, 5), activation = "relu", strides = (2, 2), padding = "same", name = "conv_5_mlo_1")(max_4_mlo)
conv_5_mlo_1 = layers.BatchNormalization(name = "bn_5_mlo_1")(conv_5_mlo_1)

conv_5_mlo_2 = layers.Conv2D(256, kernel_size = (5, 5), activation = "relu", strides = (1, 1), padding = "same", name = "conv_5_mlo_2")(conv_5_mlo_1)
conv_5_mlo_2 = layers.BatchNormalization(name = "bn_5_mlo_2")(conv_5_mlo_2)

conv_5_mlo = layers.Add(name = "add_4_mlo")([conv_5_mlo_1, conv_5_mlo_2])

max_5_mlo = layers.MaxPooling2D(pool_size = (2, 2), name = "max_5_mlo")(conv_5_mlo)




# -----------------------------------------------------------------------------------------------------------------
# Combine the output of the two branches
combined = layers.Concatenate(axis = 1, name = "combine")([max_5_cc, max_5_mlo])




# -----------------------------------------------------------------------------------------------------------------
# Add a classifier
# Flattening layer
flat = layers.Flatten(name = "flatten")(combined)

# Dense 1 layer
den_1 = layers.Dense(512, activation = "relu", name = "dense_1")(flat)
bn_den_1 = layers.BatchNormalization(name = "bn_den_1")(den_1)

# Dropout 1 Layer
drop_1 = layers.Dropout(0.4, name = "drop_out_1")(bn_den_1)

# Dense 2 layer
den_2 = layers.Dense(256, activation = "relu", name = "dense_2")(drop_1)
bn_den_2 = layers.BatchNormalization(name = "bn_den_2")(den_2)

# Dropout 2 Layer
drop_2 = layers.Dropout(0.3, name = "drop_out_2")(bn_den_2)

# Dense 3 layer
den_3 = layers.Dense(128, activation = "relu", name = "dense_3")(drop_2)
bn_den_3 = layers.BatchNormalization(name = "bn_den_3")(den_3)

# Dropout 3 Layer
drop_3 = layers.Dropout(0.3, name = "drop_out_3")(bn_den_3)

# Output layer
out = layers.Dense(1, activation = "sigmoid", name = "output")(drop_3)




# -----------------------------------------------------------------------------------------------------------------
# Define the model
model_v_d15 = Model(inputs = [input_cc, input_mlo], outputs = out, name = "CADe_v2Inputs")

# %% [markdown]
# ## Display the Architecture of the Convnet

# %%
# Print out the summary of the model
model_v_d15.summary()
# Out:
# Model: "CADe_v2Inputs"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_cc (InputLayer)          [(None, 768, 768, 1  0           []
#                                 )]
#
#  input_mlo (InputLayer)         [(None, 768, 768, 1  0           []
#                                 )]
#
#  image_rescale_cc (Rescaling)   (None, 768, 768, 1)  0           ['input_cc[0][0]']
#
#  image_rescale_mlo (Rescaling)  (None, 768, 768, 1)  0           ['input_mlo[0][0]']
#
#  conv_1_cc (Conv2D)             (None, 768, 768, 16  160         ['image_rescale_cc[0][0]']
#                                 )
#
#  conv_1_mlo (Conv2D)            (None, 768, 768, 16  160         ['image_rescale_mlo[0][0]']
#                                 )
#
#  bn_1_cc (BatchNormalization)   (None, 768, 768, 16  64          ['conv_1_cc[0][0]']
#                                 )
#
#  bn_1_mlo (BatchNormalization)  (None, 768, 768, 16  64          ['conv_1_mlo[0][0]']
#                                 )
#
#  max_1_cc (MaxPooling2D)        (None, 384, 384, 16  0           ['bn_1_cc[0][0]']
#                                 )
#
#  max_1_mlo (MaxPooling2D)       (None, 384, 384, 16  0           ['bn_1_mlo[0][0]']
#                                 )
#
#  conv_2_cc_1 (Conv2D)           (None, 384, 384, 32  4640        ['max_1_cc[0][0]']
#                                 )
#
#  conv_2_mlo_1 (Conv2D)          (None, 384, 384, 32  4640        ['max_1_mlo[0][0]']
#                                 )
#
#  bn_2_cc_1 (BatchNormalization)  (None, 384, 384, 32  128        ['conv_2_cc_1[0][0]']
#                                 )
#
#  bn_2_mlo_1 (BatchNormalization  (None, 384, 384, 32  128        ['conv_2_mlo_1[0][0]']
#  )                              )
#
#  conv_2_cc_2 (Conv2D)           (None, 384, 384, 32  9248        ['bn_2_cc_1[0][0]']
#                                 )
#
#  conv_2_mlo_2 (Conv2D)          (None, 384, 384, 32  9248        ['bn_2_mlo_1[0][0]']
#                                 )
#
#  bn_2_cc_2 (BatchNormalization)  (None, 384, 384, 32  128        ['conv_2_cc_2[0][0]']
#                                 )
#
#  bn_2_mlo_2 (BatchNormalization  (None, 384, 384, 32  128        ['conv_2_mlo_2[0][0]']
#  )                              )
#
#  add_1_cc (Add)                 (None, 384, 384, 32  0           ['bn_2_cc_1[0][0]',
#                                 )                                 'bn_2_cc_2[0][0]']
#
#  add_1_mlo (Add)                (None, 384, 384, 32  0           ['bn_2_mlo_1[0][0]',
#                                 )                                 'bn_2_mlo_2[0][0]']
#
#  max_2_cc (MaxPooling2D)        (None, 192, 192, 32  0           ['add_1_cc[0][0]']
#                                 )
#
#  max_2_mlo (MaxPooling2D)       (None, 192, 192, 32  0           ['add_1_mlo[0][0]']
#                                 )
#
#  conv_3_cc_1 (Conv2D)           (None, 192, 192, 64  18496       ['max_2_cc[0][0]']
#                                 )
#
#  conv_3_mlo_1 (Conv2D)          (None, 192, 192, 64  51264       ['max_2_mlo[0][0]']
#                                 )
#
#  bn_3_cc_1 (BatchNormalization)  (None, 192, 192, 64  256        ['conv_3_cc_1[0][0]']
#                                 )
#
#  bn_3_mlo_1 (BatchNormalization  (None, 192, 192, 64  256        ['conv_3_mlo_1[0][0]']
#  )                              )
#
#  conv_3_cc_2 (Conv2D)           (None, 192, 192, 64  36928       ['bn_3_cc_1[0][0]']
#                                 )
#
#  conv_3_mlo_2 (Conv2D)          (None, 192, 192, 64  102464      ['bn_3_mlo_1[0][0]']
#                                 )
#
#  bn_3_cc_2 (BatchNormalization)  (None, 192, 192, 64  256        ['conv_3_cc_2[0][0]']
#                                 )
#
#  bn_3_mlo_2 (BatchNormalization  (None, 192, 192, 64  256        ['conv_3_mlo_2[0][0]']
#  )                              )
#
#  add_2_cc (Add)                 (None, 192, 192, 64  0           ['bn_3_cc_1[0][0]',
#                                 )                                 'bn_3_cc_2[0][0]']
#
#  add_2_mlo (Add)                (None, 192, 192, 64  0           ['bn_3_mlo_1[0][0]',
#                                 )                                 'bn_3_mlo_2[0][0]']
#
#  max_3_cc (MaxPooling2D)        (None, 96, 96, 64)   0           ['add_2_cc[0][0]']
#
#  max_3_mlo (MaxPooling2D)       (None, 96, 96, 64)   0           ['add_2_mlo[0][0]']
#
#  conv_4_cc_1 (Conv2D)           (None, 48, 48, 128)  204928      ['max_3_cc[0][0]']
#
#  conv_4_mlo_1 (Conv2D)          (None, 48, 48, 128)  204928      ['max_3_mlo[0][0]']
#
#  bn_4_cc_1 (BatchNormalization)  (None, 48, 48, 128)  512        ['conv_4_cc_1[0][0]']
#
#  bn_4_mlo_1 (BatchNormalization  (None, 48, 48, 128)  512        ['conv_4_mlo_1[0][0]']
#  )
#
#  conv_4_cc_2 (Conv2D)           (None, 48, 48, 128)  409728      ['bn_4_cc_1[0][0]']
#
#  conv_4_mlo_2 (Conv2D)          (None, 48, 48, 128)  409728      ['bn_4_mlo_1[0][0]']
#
#  bn_4_cc_2 (BatchNormalization)  (None, 48, 48, 128)  512        ['conv_4_cc_2[0][0]']
#
#  bn_4_mlo_2 (BatchNormalization  (None, 48, 48, 128)  512        ['conv_4_mlo_2[0][0]']
#  )
#
#  add_3_cc (Add)                 (None, 48, 48, 128)  0           ['bn_4_cc_1[0][0]',
#                                                                   'bn_4_cc_2[0][0]']
#
#  add_3_mlo (Add)                (None, 48, 48, 128)  0           ['bn_4_mlo_1[0][0]',
#                                                                   'bn_4_mlo_2[0][0]']
#
#  max_4_cc (MaxPooling2D)        (None, 24, 24, 128)  0           ['add_3_cc[0][0]']
#
#  max_4_mlo (MaxPooling2D)       (None, 24, 24, 128)  0           ['add_3_mlo[0][0]']
#
#  conv_5_cc_1 (Conv2D)           (None, 12, 12, 256)  819456      ['max_4_cc[0][0]']
#
#  conv_5_mlo_1 (Conv2D)          (None, 12, 12, 256)  819456      ['max_4_mlo[0][0]']
#
#  bn_5_cc_1 (BatchNormalization)  (None, 12, 12, 256)  1024       ['conv_5_cc_1[0][0]']
#
#  bn_5_mlo_1 (BatchNormalization  (None, 12, 12, 256)  1024       ['conv_5_mlo_1[0][0]']
#  )
#
#  conv_5_cc_2 (Conv2D)           (None, 12, 12, 256)  1638656     ['bn_5_cc_1[0][0]']
#
#  conv_5_mlo_2 (Conv2D)          (None, 12, 12, 256)  1638656     ['bn_5_mlo_1[0][0]']
#
#  bn_5_cc_2 (BatchNormalization)  (None, 12, 12, 256)  1024       ['conv_5_cc_2[0][0]']
#
#  bn_5_mlo_2 (BatchNormalization  (None, 12, 12, 256)  1024       ['conv_5_mlo_2[0][0]']
#  )
#
#  add_4_cc (Add)                 (None, 12, 12, 256)  0           ['bn_5_cc_1[0][0]',
#                                                                   'bn_5_cc_2[0][0]']
#
#  add_4_mlo (Add)                (None, 12, 12, 256)  0           ['bn_5_mlo_1[0][0]',
#                                                                   'bn_5_mlo_2[0][0]']
#
#  max_5_cc (MaxPooling2D)        (None, 6, 6, 256)    0           ['add_4_cc[0][0]']
#
#  max_5_mlo (MaxPooling2D)       (None, 6, 6, 256)    0           ['add_4_mlo[0][0]']
#
#  combine (Concatenate)          (None, 12, 6, 256)   0           ['max_5_cc[0][0]',
#                                                                   'max_5_mlo[0][0]']
#
#  flatten (Flatten)              (None, 18432)        0           ['combine[0][0]']
#
#  dense_1 (Dense)                (None, 512)          9437696     ['flatten[0][0]']
#
#  bn_den_1 (BatchNormalization)  (None, 512)          2048        ['dense_1[0][0]']
#
#  drop_out_1 (Dropout)           (None, 512)          0           ['bn_den_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          131328      ['drop_out_1[0][0]']
#
#  bn_den_2 (BatchNormalization)  (None, 256)          1024        ['dense_2[0][0]']
#
#  drop_out_2 (Dropout)           (None, 256)          0           ['bn_den_2[0][0]']
#
#  dense_3 (Dense)                (None, 128)          32896       ['drop_out_2[0][0]']
#
#  bn_den_3 (BatchNormalization)  (None, 128)          512         ['dense_3[0][0]']
#
#  drop_out_3 (Dropout)           (None, 128)          0           ['bn_den_3[0][0]']
#
#  output (Dense)                 (None, 1)            129         ['drop_out_3[0][0]']
#
# ==================================================================================================
# Total params: 15,996,225
# Trainable params: 15,990,529
# Non-trainable params: 5,696
# __________________________________________________________________________________________________

# %%
# Set the png dot image file's path
dot_img_file = "logs_graph/model_v_d15.png"

# %%
tf.keras.utils.plot_model(model_v_d15, to_file = dot_img_file, show_shapes = True, rankdir = "TB")

# %% [markdown]
# ## Define Directory Paths
# - train_path contains the training images.
# - validation_path contains the validation images.
# - test_path contains the testing images.
# - Split ratio are:
#     * Training: 75%
#     * Validation: 15%
#     * Testing: 10%

# %%
# CC View
train_path_cc = "RSNA_PNG_Mammograms_Split/train_img/cc/"
validation_path_cc = "RSNA_PNG_Mammograms_Split/val_img/cc/"
test_path_cc = "RSNA_PNG_Mammograms_Split/test_img/cc/"

# MLO View
train_path_mlo = "RSNA_PNG_Mammograms_Split/train_img/mlo/"
validation_path_mlo = "RSNA_PNG_Mammograms_Split/val_img/mlo/"
test_path_mlo = "RSNA_PNG_Mammograms_Split/test_img/mlo/"

# %% [markdown]
# ## Using Image Dataset From Directory to Read Images from Directories

# %%
# Create a generator for the training images - cc view
train_generator_cc = image_dataset_from_directory(train_path_cc,
                                                  shuffle = True,
                                                  seed = shuf_seed,
                                                  image_size = (size_h, size_w), 
                                                  interpolation = inter_pol,
                                                  color_mode = "grayscale",
                                                  batch_size = bch_size,
                                                  label_mode = "binary")
# Out:
# Found 1505 files belonging to 2 classes.

# %%
# Create a generator for the training images - mlo view
train_generator_mlo = image_dataset_from_directory(train_path_mlo,
                                                   shuffle = True,
                                                   seed = shuf_seed,
                                                   image_size = (size_h, size_w), 
                                                   interpolation = inter_pol,
                                                   color_mode = "grayscale",
                                                   batch_size = bch_size,
                                                   label_mode = "binary")
# Out:
# Found 1505 files belonging to 2 classes.

# %%
# Create a generator for the validation images - cc view
validation_generator_cc = image_dataset_from_directory(validation_path_cc, 
                                                       shuffle = True,
                                                       seed = shuf_seed,
                                                       image_size = (size_h, size_w),
                                                       interpolation = inter_pol,
                                                       color_mode = "grayscale",
                                                       batch_size = bch_size,
                                                       label_mode = "binary")
# Out:
# Found 300 files belonging to 2 classes.

# %%
# Create a generator for the validation images - mlo view
validation_generator_mlo = image_dataset_from_directory(validation_path_mlo, 
                                                        shuffle = True,
                                                        seed = shuf_seed,
                                                        image_size = (size_h, size_w),
                                                        interpolation = inter_pol,
                                                        color_mode = "grayscale",
                                                        batch_size = bch_size,
                                                        label_mode = "binary")
# Out:
# Found 300 files belonging to 2 classes.

# %%
# Create a generator for the testing images - cc view
test_generator_cc = image_dataset_from_directory(test_path_cc, 
                                                 shuffle = False,
                                                 image_size = (size_h, size_w),
                                                 interpolation = inter_pol,
                                                 color_mode = "grayscale",
                                                 batch_size = bch_size,
                                                 label_mode = "binary")
# Out:
# Found 202 files belonging to 2 classes.

# %%
# Create a generator for the testing images - mlo view
test_generator_mlo = image_dataset_from_directory(test_path_mlo, 
                                                  shuffle = False,
                                                  image_size = (size_h, size_w),
                                                  interpolation = inter_pol,
                                                  color_mode = "grayscale",
                                                  batch_size = bch_size,
                                                  label_mode = "binary")
# Out:
# Found 202 files belonging to 2 classes.

# %% [markdown]
# ## Inspect the Data

# %%
# Print the class names
print("Class names: ", train_generator_cc.class_names)
print("Class names: ", train_generator_mlo.class_names)

# Inspect a batch of images and labels
def inspect_data(generator, num_batches = 1):
    for images, labels in generator.take(num_batches):
        print("Image shape:", images.shape) 
        print("Label shape:", labels.shape) 
        print("Label dtype:", labels.dtype) 
        print("Labels:", labels.numpy())
        plt.figure(figsize = (10, 10))
        for i in range(len(images)):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().squeeze(), cmap = "bone")
            plt.title(f"Label: {labels[i].numpy()}")
            plt.axis("off")
        plt.show()

inspect_data(train_generator_cc)
inspect_data(train_generator_mlo)
# Out:
# Class names:  ['cancer', 'no_cancer']
# Class names:  ['cancer', 'no_cancer']
# Image shape: (8, 768, 768, 1)
# Label shape: (8, 1)
# Label dtype: <dtype: 'float32'>
# Labels: [[1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]
# Image shape: (8, 768, 768, 1)
# Label shape: (8, 1)
# Label dtype: <dtype: 'float32'>
# Labels: [[1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
for data_batch, labels_batch in train_generator_cc:
    print("Data batch shape: ", data_batch.shape)
    print("Labels batch shape: ", labels_batch.shape)
    break
# Out:
# Data batch shape:  (8, 768, 768, 1)
# Labels batch shape:  (8, 1)

# %% [markdown]
# ## Early Stopping
# Interrupting training when the validation loss is no longer improving.

# %%
# Create the early stopping callback
early_stop = EarlyStopping(monitor = "val_PRC", 
                           patience = 16, 
                           restore_best_weights = True, 
                           verbose = 1)

# %% [markdown]
# ## Reduce Learning Rate on Plateau
# Reduce learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor = "val_PRC",
                              factor = 0.2,
                              patience = 8, 
                              min_lr = 6e-9, 
                              verbose = 1)

# %% [markdown]
# ## Model Checkpoint
# Save the current weights of the model at different points during training.

# %%
# Create the model check callback
model_check = ModelCheckpoint(filepath = "logs_model/model_v_d15.h5",
                              monitor = "val_loss",
                              save_best_only = True)

# %% [markdown]
# ## TensorBoard
# TensorBoard provides the visualization and tooling.

# %%
file_name = "model_v_d15"

# %%
tensorboard_callback = TensorBoard(log_dir = "logs_tensorboard/{}".format(file_name), histogram_freq = 1)

# %% [markdown]
# ## Learning Rate Schedule

# %% [raw]
# lr_schedule = tf.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate = 1e-2,
#     decay_steps = 10,
#     decay_rate = 0.9)

# %% [markdown]
# ## Configuring the Model

# %%
# Compile the model
model_v_d15.compile(loss = losses.BinaryCrossentropy(),
                   optimizer = optimizers.RMSprop(
                       learning_rate = 1e-3),
                   metrics = [metrics.BinaryAccuracy(name = "accuracy"),
                              metrics.Precision(name = "precision"),
                              metrics.Recall(name = "recall"),
                              metrics.AUC(name = "AUC"),
                              metrics.AUC(name = "PRC", curve = "PR")])

# %% [raw]
# # Compile the model
# model_v_d15.compile(loss = keras.losses.BinaryCrossentropy(),
#                    optimizer = keras.optimizers.SGD(
#                       learning_rate = 3e-5,
#                       momentum = 0.5,
#                       nesterov = True),
#                   metrics = [keras.metrics.BinaryAccuracy(name = "accuracy"),
#                              keras.metrics.Precision(name = "precision"),
#                              keras.metrics.Recall(name = "recall"),
#                              keras.metrics.AUC(name = "AUC")])

# %% [markdown]
# ## To Prevent the Following:
#
# - Mismatch found in batch 0
# - Labels cc view: [[0.] [0.] [0.] [0.] [1.] [0.] [0.] [0.]]
# - Labels mlo view: [[0.] [0.] [0.] [1.] [0.] [1.] [0.] [0.]]
#
# #### Please rerun the following cells.

# %%
# Create a generator for the training images - cc view
train_generator_cc = image_dataset_from_directory(train_path_cc,
                                                  shuffle = True,
                                                  seed = shuf_seed,
                                                  image_size = (size_h, size_w), 
                                                  interpolation = inter_pol,
                                                  color_mode = "grayscale",
                                                  batch_size = bch_size,
                                                  label_mode = "binary")
# Out:
# Found 1505 files belonging to 2 classes.

# %%
# Create a generator for the training images - mlo view
train_generator_mlo = image_dataset_from_directory(train_path_mlo,
                                                   shuffle = True,
                                                   seed = shuf_seed,
                                                   image_size = (size_h, size_w), 
                                                   interpolation = inter_pol,
                                                   color_mode = "grayscale",
                                                   batch_size = bch_size,
                                                   label_mode = "binary")
# Out:
# Found 1505 files belonging to 2 classes.

# %%
# Create a generator for the validation images - cc view
validation_generator_cc = image_dataset_from_directory(validation_path_cc, 
                                                       shuffle = True,
                                                       seed = shuf_seed,
                                                       image_size = (size_h, size_w),
                                                       interpolation = inter_pol,
                                                       color_mode = "grayscale",
                                                       batch_size = bch_size,
                                                       label_mode = "binary")
# Out:
# Found 300 files belonging to 2 classes.

# %%
# Create a generator for the validation images - mlo view
validation_generator_mlo = image_dataset_from_directory(validation_path_mlo, 
                                                        shuffle = True,
                                                        seed = shuf_seed,
                                                        image_size = (size_h, size_w),
                                                        interpolation = inter_pol,
                                                        color_mode = "grayscale",
                                                        batch_size = bch_size,
                                                        label_mode = "binary")
# Out:
# Found 300 files belonging to 2 classes.

# %%
# Create a generator for the testing images - cc view
test_generator_cc = image_dataset_from_directory(test_path_cc, 
                                                 shuffle = False,
                                                 image_size = (size_h, size_w),
                                                 interpolation = inter_pol,
                                                 color_mode = "grayscale",
                                                 batch_size = bch_size,
                                                 label_mode = "binary")
# Out:
# Found 202 files belonging to 2 classes.

# %%
# Create a generator for the testing images - mlo view
test_generator_mlo = image_dataset_from_directory(test_path_mlo, 
                                                  shuffle = False,
                                                  image_size = (size_h, size_w),
                                                  interpolation = inter_pol,
                                                  color_mode = "grayscale",
                                                  batch_size = bch_size,
                                                  label_mode = "binary")
# Out:
# Found 202 files belonging to 2 classes.

# %% [markdown]
# ## Training the Model

# %%
class double_generator(Sequence):
    def __init__(self, dataset_cc, dataset_mlo, batch_size):
        self.dataset_cc = dataset_cc
        self.dataset_mlo = dataset_mlo
        self.batch_size = batch_size
        self.cc_batches = list(dataset_cc.as_numpy_iterator())
        self.mlo_batches = list(dataset_mlo.as_numpy_iterator())

    def __len__(self):
        return min(len(self.cc_batches), len(self.mlo_batches))

    def __getitem__(self, idx):
        batch_cc = self.cc_batches[idx]
        batch_mlo = self.mlo_batches[idx]

        # Get the images and labels of each view
        images_cc, labels_cc = batch_cc
        images_mlo, labels_mlo = batch_mlo

        # Debugging: Print the labels to check for mismatch
        if not np.array_equal(labels_cc, labels_mlo):
            print(f"Mismatch found in batch {idx}")
            print(f"Labels cc view: {labels_cc}")
            print(f"Labels mlo view: {labels_mlo}")

        # Ensure the labels match
        assert np.array_equal(labels_cc, labels_mlo), "Labels do not match between datasets"

        # Return the images of the cc and mlo view as well as the labels of cc, which is the same as mlo's
        return [images_cc, images_mlo], labels_cc

# %%
# Training
train_generator = double_generator(train_generator_cc, train_generator_mlo, bch_size)

# Validation
validation_generator = double_generator(validation_generator_cc, validation_generator_mlo, bch_size)

# %%
# Fit the model
history = model_v_d15.fit(train_generator,
                         epochs = 16,
                         batch_size = bch_size, 
                         validation_data = validation_generator,
                         validation_batch_size = bch_size,
                         callbacks = [early_stop, reduce_lr, model_check, tensorboard_callback])
# Out:
# Epoch 1/16
# 189/189 [==============================] - 1085s 6s/step - loss: 0.9068 - accuracy: 0.5276 - precision: 0.5116 - recall: 0.5137 - AUC: 0.5259 - PRC: 0.5163 - val_loss: 0.6974 - val_accuracy: 0.5067 - val_precision: 0.4839 - val_recall: 0.3103 - val_AUC: 0.5063 - val_PRC: 0.5087 - lr: 0.0010
# Epoch 2/16
# 189/189 [==============================] - 1044s 6s/step - loss: 0.8426 - accuracy: 0.5136 - precision: 0.4971 - recall: 0.4712 - AUC: 0.5144 - PRC: 0.5014 - val_loss: 11.6483 - val_accuracy: 0.4833 - val_precision: 0.4833 - val_recall: 1.0000 - val_AUC: 0.5000 - val_PRC: 0.4833 - lr: 0.0010
# Epoch 3/16
# 189/189 [==============================] - 994s 5s/step - loss: 0.7949 - accuracy: 0.5163 - precision: 0.5000 - recall: 0.4684 - AUC: 0.5218 - PRC: 0.5068 - val_loss: 1.0502 - val_accuracy: 0.5133 - val_precision: 0.4978 - val_recall: 0.7655 - val_AUC: 0.5796 - val_PRC: 0.5848 - lr: 0.0010
# Epoch 4/16
# 189/189 [==============================] - 993s 5s/step - loss: 0.7631 - accuracy: 0.5375 - precision: 0.5240 - recall: 0.4808 - AUC: 0.5417 - PRC: 0.5275 - val_loss: 0.9330 - val_accuracy: 0.4567 - val_precision: 0.4672 - val_recall: 0.8828 - val_AUC: 0.4319 - val_PRC: 0.4467 - lr: 0.0010
# Epoch 5/16
# 189/189 [==============================] - 993s 5s/step - loss: 0.7128 - accuracy: 0.5575 - precision: 0.5438 - recall: 0.5288 - AUC: 0.5881 - PRC: 0.5619 - val_loss: 0.7579 - val_accuracy: 0.4800 - val_precision: 0.4286 - val_recall: 0.2276 - val_AUC: 0.4666 - val_PRC: 0.4678 - lr: 0.0010
# Epoch 6/16
# 189/189 [==============================] - 992s 5s/step - loss: 0.6783 - accuracy: 0.6093 - precision: 0.5980 - recall: 0.5865 - AUC: 0.6446 - PRC: 0.6044 - val_loss: 0.6370 - val_accuracy: 0.6167 - val_precision: 0.5824 - val_recall: 0.7310 - val_AUC: 0.6800 - val_PRC: 0.6588 - lr: 0.0010
# Epoch 7/16
# 189/189 [==============================] - 991s 5s/step - loss: 0.6317 - accuracy: 0.6698 - precision: 0.6555 - recall: 0.6690 - AUC: 0.7097 - PRC: 0.6817 - val_loss: 0.7581 - val_accuracy: 0.6067 - val_precision: 0.8140 - val_recall: 0.2414 - val_AUC: 0.6998 - val_PRC: 0.6836 - lr: 0.0010
# Epoch 8/16
# 189/189 [==============================] - 993s 5s/step - loss: 0.6186 - accuracy: 0.6671 - precision: 0.6583 - recall: 0.6484 - AUC: 0.7223 - PRC: 0.6826 - val_loss: 0.7881 - val_accuracy: 0.6400 - val_precision: 0.5815 - val_recall: 0.9103 - val_AUC: 0.7374 - val_PRC: 0.7079 - lr: 0.0010
# Epoch 9/16
# 189/189 [==============================] - 995s 5s/step - loss: 0.5742 - accuracy: 0.7003 - precision: 0.6889 - recall: 0.6937 - AUC: 0.7720 - PRC: 0.7336 - val_loss: 0.7117 - val_accuracy: 0.6300 - val_precision: 0.5733 - val_recall: 0.9172 - val_AUC: 0.7405 - val_PRC: 0.7254 - lr: 0.0010
# Epoch 10/16
# 189/189 [==============================] - 993s 5s/step - loss: 0.5528 - accuracy: 0.7342 - precision: 0.7228 - recall: 0.7308 - AUC: 0.7931 - PRC: 0.7597 - val_loss: 1.7127 - val_accuracy: 0.5200 - val_precision: 1.0000 - val_recall: 0.0069 - val_AUC: 0.6062 - val_PRC: 0.6232 - lr: 0.0010
# Epoch 11/16
# 189/189 [==============================] - 992s 5s/step - loss: 0.5279 - accuracy: 0.7349 - precision: 0.7238 - recall: 0.7308 - AUC: 0.8134 - PRC: 0.7845 - val_loss: 1.2287 - val_accuracy: 0.5767 - val_precision: 0.8214 - val_recall: 0.1586 - val_AUC: 0.7037 - val_PRC: 0.6939 - lr: 0.0010
# Epoch 12/16
# 189/189 [==============================] - ETA: 0s - loss: 0.4985 - accuracy: 0.7641 - precision: 0.7565 - recall: 0.7555 - AUC: 0.8389 - PRC: 0.8143
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 189/189 [==============================] - 993s 5s/step - loss: 0.4985 - accuracy: 0.7641 - precision: 0.7565 - recall: 0.7555 - AUC: 0.8389 - PRC: 0.8143 - val_loss: 1.3069 - val_accuracy: 0.5700 - val_precision: 0.9000 - val_recall: 0.1241 - val_AUC: 0.5985 - val_PRC: 0.6442 - lr: 0.0010
# Epoch 13/16
# 189/189 [==============================] - 995s 5s/step - loss: 0.4304 - accuracy: 0.8146 - precision: 0.8071 - recall: 0.8104 - AUC: 0.8837 - PRC: 0.8655 - val_loss: 0.4854 - val_accuracy: 0.7433 - val_precision: 0.7787 - val_recall: 0.6552 - val_AUC: 0.8484 - val_PRC: 0.8491 - lr: 2.0000e-04
# Epoch 14/16
# 189/189 [==============================] - 993s 5s/step - loss: 0.3756 - accuracy: 0.8372 - precision: 0.8313 - recall: 0.8324 - AUC: 0.9126 - PRC: 0.8967 - val_loss: 0.5064 - val_accuracy: 0.7667 - val_precision: 0.8151 - val_recall: 0.6690 - val_AUC: 0.8435 - val_PRC: 0.8418 - lr: 2.0000e-04
# Epoch 15/16
# 189/189 [==============================] - 994s 5s/step - loss: 0.3471 - accuracy: 0.8631 - precision: 0.8566 - recall: 0.8613 - AUC: 0.9256 - PRC: 0.9129 - val_loss: 0.5440 - val_accuracy: 0.7600 - val_precision: 0.8349 - val_recall: 0.6276 - val_AUC: 0.8380 - val_PRC: 0.8354 - lr: 2.0000e-04
# Epoch 16/16
# 189/189 [==============================] - 997s 5s/step - loss: 0.3270 - accuracy: 0.8611 - precision: 0.8465 - recall: 0.8709 - AUC: 0.9344 - PRC: 0.9250 - val_loss: 0.6026 - val_accuracy: 0.7600 - val_precision: 0.8544 - val_recall: 0.6069 - val_AUC: 0.8391 - val_PRC: 0.8474 - lr: 2.0000e-04

# %% [markdown]
# ## Call the Tensorboard

# %% [markdown]
# #### By using the following commands in the Anaconda Prompt(mini):
# - conda activate tensorflowIO
# - cd C:\Users\miche\Desktop\CM3070 Final Project Code Submission
# - tensorboard --logdir logs_tensorboard/model_...

# %% [markdown]
# ## Save the Model

# %%
# Save model
model_v_d15.save("logs_model/model_v_d15.h5")

# %% [markdown]
# ## Evaluating the Model

# %% [markdown]
# ### Evaluate using Accuracy and Loss on Training and Validation Files

# %%
print(history.params)
# Out:
# {'verbose': 1, 'epochs': 16, 'steps': 189}

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'AUC', 'PRC', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_AUC', 'val_PRC', 'lr'])

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

precision = history.history["precision"]
val_precision = history.history["val_precision"]

recall = history.history["recall"]
val_recall = history.history["val_recall"]

AUC = history.history["AUC"]
val_AUC = history.history["val_AUC"]

# %%
epochs = range(1, len(accuracy) + 1)

# %%
# Set the style of the plots
plt.style.use("seaborn-v0_8-darkgrid")

# %%
# -------------------------------------------------
# Make the plot - Accuracy
plt.figure(figsize = (8, 4))

# Define the different values
plt.plot(epochs, accuracy, "bo", label = "Training Acc")
plt.plot(epochs, val_accuracy, "r", label = "Validation Acc")

# Adding title and legend
plt.title("Training and Validation Accuracy")
plt.legend()

# -------------------------------------------------
# Make the plot - Loss
plt.figure(figsize = (8, 4))

# Define the different values
plt.plot(epochs, loss, "b--", label = "Training Loss")
plt.plot(epochs, val_loss, "r", label = "Validation Loss")

# Adding title and legend
plt.title("Training and Validation Loss")
plt.legend()


# -------------------------------------------------
# Make the plot - AUC
plt.figure(figsize = (8, 4))

# Define the different values
plt.plot(epochs, AUC, "b--", label = "Training AUC")
plt.plot(epochs, val_AUC, "r", label = "Validation AUC")

# Adding title and legend
plt.title("Training and Validation Area under the ROC Curve")
plt.legend()

# Show the plots
plt.show()

# %%
model_v_d15.metrics_names
# Out:
# ['loss', 'accuracy', 'precision', 'recall', 'AUC', 'PRC']

# %% [markdown]
# ### Evaluate using Confusion Matrix on Testing Files - CC View

# %%
test_generator = double_generator(test_generator_cc, test_generator_mlo, bch_size)

# %%
# Evaluate the model
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_PRC = model_v_d15.evaluate(test_generator)

# Print the results
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test PRC: {test_PRC}")
# Out:
# 26/26 [==============================] - 21s 812ms/step - loss: 0.4339 - accuracy: 0.8317 - precision: 0.9000 - recall: 0.7347 - AUC: 0.9059 - PRC: 0.9043
# Test Loss: 0.4339233934879303
# Test Accuracy: 0.8316831588745117
# Test Precision: 0.8999999761581421
# Test Recall: 0.7346938848495483
# Test AUC: 0.905857503414154
# Test PRC: 0.9042567014694214

# %%
# Make predictions
predictions_probs = model_v_d15.predict(test_generator)

# Print the first 10 predictions probabilities
print(predictions_probs[:10])
# Out:
# 26/26 [==============================] - 21s 807ms/step
# [[0.03012752]
#  [0.04057984]
#  [0.72835416]
#  [0.65364814]
#  [0.01237139]
#  [0.04053863]
#  [0.20321403]
#  [0.465024  ]
#  [0.05330672]
#  [0.38392848]]

# %%
# Create a predictions lists of True and False from the predictions probabilities 
predictions = predictions_probs > 0.5

# Print the first 10 predictions
print(predictions[:10])
# Out:
# [[False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]

# %%
# Convert predictions to binary labels
predicted_labels = (predictions_probs > 0.5).astype(int)

# %%
# Get the true labels from the test generator
true_labels = []

for idx in range(len(test_generator)):
    _, labels = test_generator[idx]
    true_labels.extend(labels)

true_labels = np.array(true_labels)

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.92      0.85       104
#          1.0       0.90      0.73      0.81        98
#
#     accuracy                           0.83       202
#    macro avg       0.84      0.83      0.83       202
# weighted avg       0.84      0.83      0.83       202

# %%
# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
cm
# Out:
# array([[96,  8],
#        [26, 72]], dtype=int64)

# %%
# Get class labels from the generator
class_labels = list(test_generator_cc.class_names)

# Show the class_labels
class_labels
# Out:
# ['cancer', 'no_cancer']

# %% [markdown]
# ### Confusion Matrix as a Heatmap

# %%
# Make the plot
plt.figure(figsize = (6, 6))

# Plotting
sns.heatmap(cm, 
            annot = True, 
            cmap = "GnBu", 
            fmt = "g", 
            xticklabels = class_labels, 
            yticklabels = class_labels)

# Adding labels and title
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix Heatmap")

# Show plot
plt.show()
